# %% [markdown]
# <a href="https://colab.research.google.com/github/mohinilodhi/python-library/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df.head()
# Out:
#        Nmae  age  marks status
# 0      aman   18     80   pass
# 1    aditya   19     90   fail
# 2     rahul   20     88   pass
# 3  aakancha   18     89   pass
# 4     jyoti   19     99   fail

# %%
import pandas as pd

data = {
    "Nmae":["aman","aditya","rahul","aakancha","jyoti"],
    "age":[18,19,20,18,19],
    "marks":[80,90,88,89,99]
}
df = pd.DataFrame(data)
print(df)
# Out:
#        Nmae  age  marks
# 0      aman   18     80
# 1    aditya   19     90
# 2     rahul   20     88
# 3  aakancha   18     89
# 4     jyoti   19     99

# %%
df.tail()
# Out:
#        Nmae  age  marks
# 0      aman   18     80
# 1    aditya   19     90
# 2     rahul   20     88
# 3  aakancha   18     89
# 4     jyoti   19     99

# %%
df.shape
# Out:
# (5, 3)

# %%
df.size
# Out:
# 15

# %%
df.columns
# Out:
# Index(['Nmae', 'age', 'marks'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nmae    5 non-null      object
#  1   age     5 non-null      int64
#  2   marks   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df["Nmae"]
# Out:
# 0        aman
# 1      aditya
# 2       rahul
# 3    aakancha
# 4       jyoti
# Name: Nmae, dtype: object

# %%
df["marks"]
# Out:
# 0    80
# 1    90
# 2    88
# 3    89
# 4    99
# Name: marks, dtype: int64

# %%
df[["Nmae","age"]]
# Out:
#        Nmae  age
# 0      aman   18
# 1    aditya   19
# 2     rahul   20
# 3  aakancha   18
# 4     jyoti   19

# %%
df["marks"].mean()
# Out:
# np.float64(89.2)

# %%
df["marks"].max()
# Out:
# 99

# %%
df["marks"].min()
# Out:
# 80

# %%
df["marks"].sum()
# Out:
# np.int64(446)

# %%
df[df["marks"] > 80]
# Out:
#        Nmae  age  marks
# 1    aditya   19     90
# 2     rahul   20     88
# 3  aakancha   18     89
# 4     jyoti   19     99

# %%
df[df["age"] == 18]
# Out:
#        Nmae  age  marks
# 0      aman   18     80
# 3  aakancha   18     89

# %%
df.sort_values(by="marks")
# Out:
#        Nmae  age  marks
# 0      aman   18     80
# 2     rahul   20     88
# 3  aakancha   18     89
# 1    aditya   19     90
# 4     jyoti   19     99

# %%
df.sort_values(by="marks",ascending=False)
# Out:
#        Nmae  age  marks
# 4     jyoti   19     99
# 1    aditya   19     90
# 3  aakancha   18     89
# 2     rahul   20     88
# 0      aman   18     80

# %%
df["status"] = ["pass","fail","pass","pass","fail"]
print(df)
# Out:
#        Nmae  age  marks status
# 0      aman   18     80   pass
# 1    aditya   19     90   fail
# 2     rahul   20     88   pass
# 3  aakancha   18     89   pass
# 4     jyoti   19     99   fail
